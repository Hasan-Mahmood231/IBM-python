# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df['size'].unique() # means we have uniqu value which is this
# Out:
# array([2, 3, 4, 1, 6, 5])

# %%
plt.subplot(1,2,1)
sns.histplot(df['total_bill'],kde=True,color='grey',bins=10)
plt.subplot(1,2,2)
sns.histplot(df['tip'],kde=True,color='grey',bins=10)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
sns.jointplot(x = 'total_bill',y = 'tip',data=df,color='grey')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.jointplot(x = 'total_bill',y = 'tip',data= df, color= 'green', kind= 'resid')

# %%
sns.jointplot(x = 'total_bill',y= 'tip',data= df,kind= 'reg',color='grey')

# %%
data = {
    "Height": [150, 160, 170, 180, 175],
    "Weight": [45, 55, 65, 70, 68],
    "Marks":  [70, 80, 75, 90, 85]
}

df2 = pd.DataFrame(data)

sns.pairplot(df2)
plt.show()

# %%
sns.pairplot(df,hue='size',palette='rainbow')

# %% [markdown]
# ## Categorical Data :

# %%
cdf = sns.load_dataset('tips')
cdf
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.countplot(x = df['sex'])
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
#want to check how many male and female smoker across the data.
sns.countplot(x= cdf['sex'],hue= cdf['smoker'])
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.barplot(x= cdf['sex'],y= cdf['total_bill'])
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
import numpy as np
sns.barplot(x = cdf['sex'], y = cdf['total_bill'],estimator= np.sum,color='grey')
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
sns.scatterplot(x= 'tip',y= 'total_bill',data=cdf,)
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %%
sns.stripplot(x= 'day',y = 'tip', data= cdf,color='grey')
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.violinplot(x = 'day',y = 'tip', data= cdf,color= 'grey')
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
cdf
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
import pandas as pd
pvt = pd.pivot_table(index= 'total_bill',columns='day',values= 'tip',aggfunc='sum',data= cdf)
# Out:
# C:\Users\hassa\AppData\Local\Temp\ipykernel_10224\2755530082.py:2: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   pvt = pd.pivot_table(index= 'total_bill',columns='day',values= 'tip',aggfunc='sum',data= cdf)

# %%
sns.heatmap(pvt)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>
