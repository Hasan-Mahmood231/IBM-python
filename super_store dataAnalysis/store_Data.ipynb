# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('SampleSuperstore.csv')
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
df.shape
# Out:
# (9994, 13)

# %%
# df.isnull().sum()
df.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
df['Ship Mode'].value_counts()
# Out:
# Ship Mode
# Standard Class    5968
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: count, dtype: int64

# %%
sns.countplot(x = 'Ship Mode',data= df)
plt.show()

# %%
df['Segment'].value_counts()
# Out:
# Segment
# Consumer       5191
# Corporate      3020
# Home Office    1783
# Name: count, dtype: int64

# %%
sns.countplot(x= 'Segment',data=df)
plt.show()

# %% [markdown]
# - we have more consumer then others

# %%
# df['Country'].value_counts()  #the country is US
x = df['City'].value_counts()[:10].index
y = df['City'].value_counts()[:10].values

# %%
plt.pie(x=y,labels=x,autopct='%1.2f%%',data=df)
plt.show()

# %%
# df['State'].value_counts().count()
df['State'].nunique()
# Out:
# 49

# %%
top_state = df['State'].value_counts().nlargest(10)

# %%
# df['State'].value_counts().nlargest(20)

# %%
top_city = df.groupby('City')['Sales'].sum().sort_values(ascending=False).head(10)

# %%
top_city.plot(kind='bar')
# Out:
# <Axes: xlabel='City'>
