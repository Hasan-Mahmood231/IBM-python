# %%
import numpy as np
import pandas as pd

data = {
    'Name' : ["Hassan","shahid","saim"],
    'Age' : [32,4,2,],
    'Gender' :  [32,4,2,],
 }

df = pd.DataFrame(data)
df
# Out:
#      Name  Age  Gender
# 0  Hassan   32      32
# 1  shahid    4       4
# 2    saim    2       2

# %%
list_Data = [
    ["hassan","shahid","saim"],
    [32,4,2,],
    [32,4,2,],
]

ls = pd.DataFrame(list_Data)
colum = ["Math","Physics" ,"CS"]
ls = pd.DataFrame(list_Data,columns=colum)      #Assigne column directly by list
ls
# Out:
#      Math Physics    CS
# 0  hassan  shahid  saim
# 1      32       4     2
# 2      32       4     2

# %%
ls["Selery"] = [23000,90000,135000]
ls
# Out:
#      Math Physics    CS  Selery
# 0  hassan  shahid  saim   23000
# 1      32       4     2   90000
# 2      32       4     2  135000

# %%
new_data = ls.drop("CS",axis=1)    #it only drop data temprereee untile we use inplace = ture
new_data
# Out:
#      Math Physics  Selery
# 0  hassan  shahid   23000
# 1      32       4   90000
# 2      32       4  135000

# %%
#Let take the only physics makrks so 
ls["Physics"]
# Out:
# 0    shahid
# 1         4
# 2         4
# Name: Physics, dtype: object

# %%
ls.loc[3] = [90,44,98,110000]       #the ls is object where we store the actual data
ls
# Out:
#      Math Physics    CS  Selery
# 0  hassan  shahid  saim   23000
# 1      32       4     2   90000
# 2      32       4     2  135000
# 3      90      44    98  110000

# %%
#want to select only (2) row so
ls.loc[2]
# Out:
# Math           32
# Physics         4
# CS              2
# Selery     135000
# Name: 2, dtype: object

# %%
#remove the 1st row for now so
ls.drop(1)
# Out:
#      Math Physics    CS  Selery
# 0  hassan  shahid  saim   23000
# 2      32       4     2  135000
# 3      90      44    98  110000

# %%
ls
# Out:
#      Math Physics    CS  Selery
# 0  hassan  shahid  saim   23000
# 1      32       4     2   90000
# 2      32       4     2  135000
# 3      90      44    98  110000

# %% [markdown]
# Slicing of Datafram

# %%
subset = ls.loc[[1,2],["Physics","CS"]]
subset
# Out:
#   Physics CS
# 1       4  2
# 2       4  2

# %%
ls.loc[[1,2],["Physics","CS"]] = [23,90]
ls
# Out:
#      Math Physics    CS  Selery
# 0  hassan  shahid  saim   23000
# 1      32      23    90   90000
# 2      32      23    90  135000
# 3      90      44    98  110000

# %%
ls.loc[0] = [67,29,88000,12]
ls
# Out:
#   Math Physics     CS  Selery
# 0   67      29  88000      12
# 1   32      23     90   90000
# 2   32      23     90  135000
# 3   90      44     98  110000

# %% [markdown]
# Change Marks inbetween

# %%
ls.loc[[1,2],["CS"]] = [56,77]
ls
# Out:
#   Math Physics     CS  Selery
# 0   67      29  88000      12
# 1   32      23     56   90000
# 2   32      23     77  135000
# 3   90      44     98  110000

# %%
ls["Name"] = ["ALI","saqib","shauyan","qazi"]
ls
# Out:
#   Math Physics     CS  Selery     Name
# 0   67      29  88000      12      ALI
# 1   32      23     56   90000    saqib
# 2   32      23     77  135000  shauyan
# 3   90      44     98  110000     qazi

# %%
# ls["Name","Math","Physics","CS","Selery"]
ls
# Out:
#   Math Physics     CS  Selery     Name
# 0   67      29  88000      12      ALI
# 1   32      23     56   90000    saqib
# 2   32      23     77  135000  shauyan
# 3   90      44     98  110000     qazi

# %%
ls[(ls["Math"] >30) & (ls["Physics"] > 29)]
# Out:
#   Math Physics  CS  Selery  Name
# 3   90      44  98  110000  qazi

# %% [markdown]
# # Miss values :

# %%
data2 = {
    "Name": ["Ali", "Sara", "Ahmed", "Zara", "Bilal"],
    "Math": [67, 45, None, 82, 29],
    "Physics": [29, None, 55, 40, 18],
    "CS": [88, 72, 91, None, 60],
    "English": [75, 64, None, 59, None]
}
df2 = pd.DataFrame(data2)
df2
# Out:
#     Name  Math  Physics    CS  English
# 0    Ali  67.0     29.0  88.0     75.0
# 1   Sara  45.0      NaN  72.0     64.0
# 2  Ahmed   NaN     55.0  91.0      NaN
# 3   Zara  82.0     40.0   NaN     59.0
# 4  Bilal  29.0     18.0  60.0      NaN

# %%
df2.isna().sum()
# Out:
# Name       0
# Math       1
# Physics    1
# CS         1
# English    2
# dtype: int64

# %%
df2
# Out:
#     Name  Math  Physics    CS  English
# 0    Ali  67.0     29.0  88.0     75.0
# 1   Sara  45.0      NaN  72.0     64.0
# 2  Ahmed   NaN     55.0  91.0      NaN
# 3   Zara  82.0     40.0   NaN     59.0
# 4  Bilal  29.0     18.0  60.0      NaN

# %%
new = df2.drop(columns="Name") # drop the name colmn for finding mean

# %%
df2.fillna(new.mean(),inplace=True)

# %%
df2.loc[:,"Math":] #by slicng we find this
# Out:
#    Math  Physics    CS  English
# 0  67.0     29.0  88.0     75.0
# 1  45.0      NaN  72.0     64.0
# 2   NaN     55.0  91.0      NaN
# 3  82.0     40.0   NaN     59.0
# 4  29.0     18.0  60.0      NaN

# %%
new
# Out:
#    Math  Physics    CS  English
# 0  67.0     29.0  88.0     75.0
# 1  45.0      NaN  72.0     64.0
# 2   NaN     55.0  91.0      NaN
# 3  82.0     40.0   NaN     59.0
# 4  29.0     18.0  60.0      NaN

# %%
pd.concat([new,df2])    #concat by row direct bcz the axis = 0
# Out:
#    Math  Physics    CS  English   Name
# 0  67.0     29.0  88.0     75.0    NaN
# 1  45.0      NaN  72.0     64.0    NaN
# 2   NaN     55.0  91.0      NaN    NaN
# 3  82.0     40.0   NaN     59.0    NaN
# 4  29.0     18.0  60.0      NaN    NaN
# 0  67.0     29.0  88.0     75.0    Ali
# 1  45.0      NaN  72.0     64.0   Sara
# 2   NaN     55.0  91.0      NaN  Ahmed
# 3  82.0     40.0   NaN     59.0   Zara
# 4  29.0     18.0  60.0      NaN  Bilal

# %%
pd.concat([new,df2], axis=True)
# Out:
#    Math  Physics    CS  English   Name  Math  Physics    CS  English
# 0  67.0     29.0  88.0     75.0    Ali  67.0     29.0  88.0     75.0
# 1  45.0      NaN  72.0     64.0   Sara  45.0      NaN  72.0     64.0
# 2   NaN     55.0  91.0      NaN  Ahmed   NaN     55.0  91.0      NaN
# 3  82.0     40.0   NaN     59.0   Zara  82.0     40.0   NaN     59.0
# 4  29.0     18.0  60.0      NaN  Bilal  29.0     18.0  60.0      NaN

# %%
df2
# Out:
#     Name   Math  Physics     CS  English
# 0    Ali  67.00     29.0  88.00     75.0
# 1   Sara  45.00     35.5  72.00     64.0
# 2  Ahmed  55.75     55.0  91.00     66.0
# 3   Zara  82.00     40.0  77.75     59.0
# 4  Bilal  29.00     18.0  60.00     66.0

# %%
df2.groupby("English")["English"].sum()
# Out:
# English
# 59.0     59.0
# 64.0     64.0
# 66.0    132.0
# 75.0     75.0
# Name: English, dtype: float64
