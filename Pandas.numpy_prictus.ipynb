# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r'DEvideos.csv')
df.head()
# Out:
#       video_id trending_date  \
# 0  LgVi6y5QIjM      17.14.11
# 1  Bayt7uQith4      17.14.11
# 2  1ZAPwfrtAFY      17.14.11
# 3  AHtypnRk7JE      17.14.11
# 4  ZJ9We4bjcg0      17.14.11
#
#                                                title            channel_title  \
# 0  Sing zu Ende! | Gesangseinlagen vom Feinsten |...                inscope21
# 1  Kinder ferngesteuert im Kiosk! Erwachsene abzo...  LUKE! Die Woche und ich
# 2  The Trump Presidency: Last Week Tonight with J...          LastWeekTonight
# 3                                Das Fermi-Paradoxon        100SekundenPhysik
# 4           18 SONGS mit Kelly MissesVlog (Sing-off)                     rezo
#
#    category_id              publish_time  \
# 0           24  2017-11-13T17:08:49.000Z
# 1           23  2017-11-12T22:30:01.000Z
# 2           24  2017-11-13T07:30:00.000Z
# 3           27  2017-11-12T15:00:01.000Z
# 4           24  2017-11-12T13:10:36.000Z
#
# ...

# %%
df.drop(['thumbnail_link','tags','description'],axis=1,inplace=True)
df
# Out:
#           video_id trending_date  \
# 0      LgVi6y5QIjM      17.14.11
# 1      Bayt7uQith4      17.14.11
# 2      1ZAPwfrtAFY      17.14.11
# 3      AHtypnRk7JE      17.14.11
# 4      ZJ9We4bjcg0      17.14.11
# ...            ...           ...
# 40835  fn5WNxy-Wcw      18.14.06
# 40836  zAFv43lxqHE      18.14.06
# 40837  zSXG5I6Y2fA      18.14.06
# 40838  5d115sePmaU      18.14.06
# 40839  go-F6xvezAM      18.14.06
#
#                                                    title  \
# 0      Sing zu Ende! | Gesangseinlagen vom Feinsten |...
# 1      Kinder ferngesteuert im Kiosk! Erwachsene abzo...
# 2      The Trump Presidency: Last Week Tonight with J...
# 3                                    Das Fermi-Paradoxon
# 4               18 SONGS mit Kelly MissesVlog (Sing-off)
# ...                                                  ...
# 40835  KINGDOM HEARTS III – E3 2018 Pirates of the Ca...
# 40836                                     YMS: The Visit
# ...

# %%
df.shape
# Out:
# (40840, 13)

# %%
df.isna().sum()
df[df['dislikes'].isna()]
# Out:
# Empty DataFrame
# Columns: [video_id, trending_date, title, channel_title, category_id, publish_time, views, likes, dislikes, comment_count, comments_disabled, ratings_disabled, video_error_or_removed]
# Index: []

# %%
df[df['publish_time'].pe]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10192\3322877392.py in ?()
# ----> 1 df[df['publish_time'].pe]
#
# c:\Users\hassa\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'pe'

# %% [markdown]
# Practice Questions (Total = 13)
#
# Shape of dataset
# → Find how many rows and columns are in the dataset.
#
# Column info
# → Show the names of all columns and their data types.
#
# Missing values
# → Find how many missing values are in each column.
#
# Unique categories
# → How many unique category_id values exist?
#
# Most common channel
# → Which channel_title uploaded the most videos in this dataset?
#
# Top 5 most viewed videos
# → Get the top 5 rows with highest views.
#
# Average likes per category
# → For each category_id, find the average number of likes.
#
# Videos with disabled comments
# → Count how many videos have comments_disabled = True.
#
# Videos with more dislikes than likes
# → Find all rows where dislikes > likes.
#
# Trending date conversion
# → Convert trending_date into proper datetime format.
#
# Publish hour
# → Extract the hour from publish_time column.
#
# Correlation
# → Check correlation between views, likes, dislikes, and comment_count.
#
# Like ratio
# → Create a new column like_ratio = likes / (likes + dislikes) and show the top 10 videos with the highest ratio.````

# %%
df.head()
# Out:
#       video_id trending_date  \
# 0  LgVi6y5QIjM      17.14.11
# 1  Bayt7uQith4      17.14.11
# 2  1ZAPwfrtAFY      17.14.11
# 3  AHtypnRk7JE      17.14.11
# 4  ZJ9We4bjcg0      17.14.11
#
#                                                title            channel_title  \
# 0  Sing zu Ende! | Gesangseinlagen vom Feinsten |...                inscope21
# 1  Kinder ferngesteuert im Kiosk! Erwachsene abzo...  LUKE! Die Woche und ich
# 2  The Trump Presidency: Last Week Tonight with J...          LastWeekTonight
# 3                                Das Fermi-Paradoxon        100SekundenPhysik
# 4           18 SONGS mit Kelly MissesVlog (Sing-off)                     rezo
#
#    category_id              publish_time    views   likes  dislikes  \
# 0           24  2017-11-13T17:08:49.000Z   252786   35885       230
# 1           23  2017-11-12T22:30:01.000Z   797196   53576       302
# 2           24  2017-11-13T07:30:00.000Z  2418783   97190      6146
# ...

# %%
#→ Find how many rows and columns are in the dataset.
row_col = df.shape
print(f"There are {row_col} rows and cols in dataset")
# Out:
# There are (40840, 13) rows and cols in dataset

# %%
#→ Show the names of all columns and their data types.
column = df.columns
data_type = df.dtypes
print(f"The column of dataset is {column}\nThe data type of column is {data_type}")
# Out:
# The column of dataset is Index(['video_id', 'trending_date', 'title', 'channel_title', 'category_id',
#        'publish_time', 'views', 'likes', 'dislikes', 'comment_count',
#        'comments_disabled', 'ratings_disabled', 'video_error_or_removed'],
#       dtype='object')
# The data type of column is video_id                  object
# trending_date             object
# title                     object
# channel_title             object
# category_id                int64
# publish_time              object
# views                      int64
# likes                      int64
# dislikes                   int64
# comment_count              int64
# comments_disabled           bool
# ratings_disabled            bool
# video_error_or_removed      bool
# dtype: object

# %%
#→ Find how many missing values are in each column.
if df.isna().sum().sum() == 0:
    print("No NULL values are present.")
else:
    df.isna().sum().sum()
# Out:
# No NULL values are present.

# %%
#→ How many unique category_id values exist?
df['category_id'].unique()
# Out:
# array([24, 23, 27, 22,  1,  2, 17, 26, 25, 10, 20, 43, 28, 29, 15, 19, 44,
#        30])

# %%
df.head(2)
# Out:
#       video_id trending_date  \
# 0  LgVi6y5QIjM      17.14.11
# 1  Bayt7uQith4      17.14.11
#
#                                                title            channel_title  \
# 0  Sing zu Ende! | Gesangseinlagen vom Feinsten |...                inscope21
# 1  Kinder ferngesteuert im Kiosk! Erwachsene abzo...  LUKE! Die Woche und ich
#
#    category_id              publish_time   views  likes  dislikes  \
# 0           24  2017-11-13T17:08:49.000Z  252786  35885       230
# 1           23  2017-11-12T22:30:01.000Z  797196  53576       302
#
#    comment_count  comments_disabled  ratings_disabled  video_error_or_removed
# 0           1539              False             False                   False
# 1           1278              False             False                   False

# %%
#→ Which channel_title uploaded the most videos in this dataset?

channel = df['channel_title'].value_counts().idxmax()
print(f"The channel which uploaded most video is {channel}")
# Out:
# The channel which uploaded most video is Galileo

# %%
#Get the top 5 rows with highest views.
df.nlargest(5,'views')
# Out:
#          video_id trending_date  \
# 5455  FlsCjmMhFmw      17.11.12
# 5221  FlsCjmMhFmw      17.10.12
# 4062  6ZfuNTqbHE8      17.04.12
# 5004  FlsCjmMhFmw      17.09.12
# 3808  6ZfuNTqbHE8      17.03.12
#
#                                                   title         channel_title  \
# 5455  YouTube Rewind: The Shape of 2017 | #YouTubeRe...     YouTube Spotlight
# 5221  YouTube Rewind: The Shape of 2017 | #YouTubeRe...     YouTube Spotlight
# 4062  Marvel Studios' Avengers: Infinity War Officia...  Marvel Entertainment
# 5004  YouTube Rewind: The Shape of 2017 | #YouTubeRe...     YouTube Spotlight
# 3808  Marvel Studios' Avengers: Infinity War Officia...  Marvel Entertainment
#
#       category_id              publish_time      views    likes  dislikes  \
# 5455           24  2017-12-06T17:58:51.000Z  113876217  2811217   1470386
# 5221           24  2017-12-06T17:58:51.000Z  100911567  2656675   1353652
# ...

# %%
#Average likes per category
#→ For each category_id, find the average number of likes.
avg = df.groupby('category_id')['likes'].mean()
avg.round(2)
# Out:
# category_id
# 1      19072.20
# 2       7037.07
# 10    126600.79
# 15     13350.80
# 17     13679.66
# 19      6291.04
# 20     18446.19
# 22     10173.69
# 23     29513.58
# 24     17509.30
# 25      4903.54
# 26      8654.37
# 27      8906.14
# 28     19073.04
# 29     57034.97
# 30     31917.00
# 43      3540.36
# 44         0.00
# Name: likes, dtype: float64

# %%
#→ Count how many videos have comments_disabled = True

# %%
df['comments_disabled'].sum()
len(df) - df['comments_disabled'].sum()
# Out:
# np.int64(39796)

# %%
df.head()
# Out:
#       video_id trending_date  \
# 0  LgVi6y5QIjM      17.14.11
# 1  Bayt7uQith4      17.14.11
# 2  1ZAPwfrtAFY      17.14.11
# 3  AHtypnRk7JE      17.14.11
# 4  ZJ9We4bjcg0      17.14.11
#
#                                                title            channel_title  \
# 0  Sing zu Ende! | Gesangseinlagen vom Feinsten |...                inscope21
# 1  Kinder ferngesteuert im Kiosk! Erwachsene abzo...  LUKE! Die Woche und ich
# 2  The Trump Presidency: Last Week Tonight with J...          LastWeekTonight
# 3                                Das Fermi-Paradoxon        100SekundenPhysik
# 4           18 SONGS mit Kelly MissesVlog (Sing-off)                     rezo
#
#    category_id              publish_time    views   likes  dislikes  \
# 0           24  2017-11-13T17:08:49.000Z   252786   35885       230
# 1           23  2017-11-12T22:30:01.000Z   797196   53576       302
# 2           24  2017-11-13T07:30:00.000Z  2418783   97190      6146
# ...

# %%
high_comment = df[df['comment_count'] == df['comment_count'].max()]
high_likes = df[df['likes'] == df['likes'].max()]
high_likes
high_comment
# if high_comment > high_likes:
#     print("high_comment")
# else:
#     print("high_likes")
# Out:
#           video_id trending_date                                title  \
# 36291  7C2z4GqqS5E      18.22.05  BTS (방탄소년단) 'FAKE LOVE' Official MV
#
#       channel_title  category_id              publish_time     views    likes  \
# 36291       ibighit           10  2018-05-18T09:00:02.000Z  73463137  4924056
#
#        dislikes  comment_count  comments_disabled  ratings_disabled  \
# 36291    156026        1084435              False             False
#
#        video_error_or_removed
# 36291                   False
